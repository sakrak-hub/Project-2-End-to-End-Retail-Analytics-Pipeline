# %%
import pandas as pd
from data_generator_2 import RetailDataGenerator
from datetime import datetime
import boto3
# Out:
# The kernel failed to start as the Python Environment 'Python' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
data = pd.read_parquet('/mnt/d/Projects/Project-2-End-to-End-Retail-Analytics-Pipeline/retail_data_v2/transactions_2025-01-01.parquet')
data
# Out:
#             transaction_id       date      time            datetime  \
# 0        TXN20250101000001        NaT      None                 NaT
# 1        TXN20250101000001        NaT      None                 NaT
# 2        TXN20250101000002 2025-01-01  19:19:48 2025-01-28 19:19:48
# 3        TXN20250101000002 2025-01-01  19:19:48 2025-01-28 19:19:48
# 4        TXN20250101000002 2025-01-01  19:19:48 2025-01-28 19:19:48
# ...                    ...        ...       ...                 ...
# 9459  DUPTXN20250101002394 2025-01-01  23:05:39 2025-01-01 23:05:39
# 9460  DUPTXN20250101000075 2025-01-01  12:51:19 2025-01-01 12:51:19
# 9461  DUPTXN20250101000075 2025-01-01  12:51:19 2025-01-01 12:51:19
# 9462  DUPTXN20250101000075 2025-01-01  12:51:19 2025-01-01 12:51:19
# 9463  DUPTXN20250101003895 2025-01-01  19:18:00 2025-01-01 19:18:00
#
#      customer_id store_id                   store_name cashier_id  \
# 0     CUST011266    ST005          Spence PLC Flagship     EMP049
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9464 entries, 0 to 9463
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   transaction_id         9464 non-null   object
#  1   date                   9015 non-null   datetime64[ns]
#  2   time                   9015 non-null   object
#  3   datetime               9015 non-null   datetime64[ns]
#  4   customer_id            9464 non-null   object
#  5   store_id               9464 non-null   object
#  6   store_name             9464 non-null   object
#  7   cashier_id             7627 non-null   object
#  8   payment_method         8505 non-null   object
#  9   subtotal               9464 non-null   float64
#  10  tax_amount             9464 non-null   float64
#  11  total_amount           9464 non-null   float64
#  12  items_count            9464 non-null   int64
#  13  loyalty_points_earned  9464 non-null   int64
# ...

# %%
import os
# Out:
# The kernel failed to start as the Python Environment 'Python' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
